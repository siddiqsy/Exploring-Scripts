# %%
with open('addata.txt') as f:
    contents = f.read()
    print(contents)

# %%
import urllib

# %%
for line in urllib.request.urlopen("https://www.yahoo.com/ads.txt"):
    print(line)
# Out:
# b'#2022-06-09\n'
# b'\n'
# b'# ownerdomain=yahooinc.com\n'
# b'\n'
# b'#NAR\n'
# b'\n'
# b'#NAR Direct\n'
# b'advertising.com, 3679, DIRECT #video, US\n'
# b'advertising.com, 28090, DIRECT\n'
# b'yahoo.com, 1, DIRECT #native\n'
# b'yahoo.com, 52469, DIRECT #display, Yahoo\n'
# b'yahoo.com, 57316, DIRECT #display, AOL\n'
# b'yahoo.com, 57322, DIRECT #display, AOL\n'
# b'yahoo.com, 2c44cbf8d10e3e7e1a28056c484eac0bde0af585, DIRECT #native\n'
# b'yahoo.com, 29284317594, DIRECT #banner\n'
# b'yahoo.com, 20459933223, DIRECT #banner\n'
# b'yahoo.com, 20764982904, DIRECT #banner\n'
# b'yahoo.com, 25980889636, DIRECT #banner, CA\n'
# b'yahoo.com, 26720242308, DIRECT #banner, CA\n'
# b'yahoo.com, 29284317576, DIRECT #banner\n'
# b'yahoo.com, 29284317581, DIRECT #banner, video\n'
# b'yahoo.com, 29228548013, DIRECT #banner, US\n'
# b'yahoo.com, 55990, DIRECT #Native\n'
# b'yahoo.com, 58761, DIRECT\n'
# b'\n'
# b'#ABP\n'
# b'aax.media, AAXT6MET1, DIRECT #abp\n'
# ...

# %%
import pandas as pd
cols = ['Domain','Code','Type','Source']
df = pd.read_fwf(r'C:\Users\siddi\Desktop\addata.txt', 
                 header=None, delimiter=",",
                 names=cols)

# %%
df.head(10)
# Out:
#                                      Domain  Code  Type  Source
# 0                               #2022-06-09   NaN   NaN     NaN
# 1                # ownerdomain=yahooinc.com   NaN   NaN     NaN
# 2                                      #NAR   NaN   NaN     NaN
# 3                               #NAR Direct   NaN   NaN     NaN
# 4  advertising.com, 3679, DIRECT #video, US   NaN   NaN     NaN
# 5            advertising.com, 28090, DIRECT   NaN   NaN     NaN
# 6              yahoo.com, 1, DIRECT #native   NaN   NaN     NaN
# 7  yahoo.com, 52469, DIRECT #display, Yahoo   NaN   NaN     NaN
# 8    yahoo.com, 57316, DIRECT #display, AOL   NaN   NaN     NaN
# 9    yahoo.com, 57322, DIRECT #display, AOL   NaN   NaN     NaN

# %%
df_grouped = df.groupby(['Domain', 'Type']).size()

# %%
df_grouped
# Out:
# Domain  Type
# # owne  in=yaho    1
# #APAC   t          1
# #AUNZ   t          1
# #Daily  n          1
# #EMEA   t          1
#                   ..
# yahoo.  991644,    1
# yieldm  , 22094    1
#         , 27240    1
#         , 27376    1
#         , 28253    1
# Length: 360, dtype: int64

# %%
    def reverseWords(s):
        """
        :type s: str
        :rtype: str
        """
        words = s.split(' ')
        
        ans = ""
    
        for w in words:
            ans + w[::-1] + ''
        return ans[0:len(ans) - 1]

# %%
print(reverseWords('Let\'s take LeetCode contest'))

# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\siddi\Downloads\russia_losses_equipment.csv")

# %%
df.head(3)
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0          100.0       60.0      0           2                      0
# 1          130.0       60.0      2           2                      0
# 2          130.0       60.0      2           2                      0
#
#    special equipment  mobile SRBM system greatest losses direction  \
# 0                NaN                 NaN                       NaN
# 1                NaN                 NaN                       NaN
# 2                NaN                 NaN                       NaN
#
#    vehicles and fuel tanks  cruise missiles
# 0                      NaN              NaN
# ...

# %%
df2 = pd.read_csv(r"c:\Users\siddi\Downloads\russia_losses_personnel.csv")

# %%
df2.head(3)
# Out:
#          date  day  personnel personnel*  POW
# 0  2022-02-25    2       2800      about  0.0
# 1  2022-02-26    3       4300      about  0.0
# 2  2022-02-27    4       4500      about  0.0

# %%
list1 = [12, 16, 20, 20, 12, 30, 25, 23, 24, 20]
mean = sum(list1)/len(list1)
print(mean)
# Out:
# 20.2

# %%
list1 = [12, 16, 20, 20, 12, 30, 25, 23, 24, 20]
list1.sort()

if len(list1) % 2 == 0:
    m1 = list1[len(list1)//2]
    m2 = list1[len(list1)//2 - 1]
    median = (m1 + m2)/2
else:
    median = list1[len(list1)//2]
print(median)
# Out:
# 20.0

# %%
list1 = [12, 16, 20, 20, 12, 30, 25, 23, 24, 20]
frequency = {}
for i in list1:
    frequency.setdefault(i, 0)
    frequency[i]+=1

frequent = max(frequency.values())
for i, j in frequency.items():
    if j == frequent:
        mode = i
print(mode)
# Out:
# 20

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity

data = pd.read_csv(r"C:\Users\siddi\Downloads\netflixData.csv\netflixData.csv")
print(data.head())
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
data = data[["Title", "Description", "Content Type", "Genres"]]
print(data.head())
# Out:
#                            Title  \
# 0                       (Un)Well
# 1                         #Alive
# 2  #AnneFrank - Parallel Stories
# 3                       #blackAF
# 4               #cats_the_mewvie
#
#                                          Description Content Type  \
# 0  This docuseries takes a deep dive into the luc...      TV Show
# 1  As a grisly virus rampages a city, a lone man ...        Movie
# 2  Through her diary, Anne Frank's story is retol...        Movie
# 3  Kenya Barris and his family navigate relations...      TV Show
# 4  This pawesome documentary explores how our fel...        Movie
#
#                                            Genres
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
# 3                                     TV Comedies
# 4             Documentaries, International Movies

# %%
data = data.dropna()

# %%
import nltk
import re
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data["Title"] = data["Title"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\siddi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
print(data.Title.sample(10))
# Out:
# 5793                    what raashe
# 3549                      oper ouch
# 5429    tom papa live new york citi
# 4216                     shes gotta
# 375                           anima
# 4583           termin  judgment day
# 950                           cheer
# 340                ami schumer grow
# 4586      terrac hous open new door
# 3494                       okko inn
# Name: Title, dtype: object

# %%
feature = data["Genres"].tolist()
tfidf = text.TfidfVectorizer(input=feature, stop_words="english")
tfidf_matrix = tfidf.fit_transform(feature)
similarity = cosine_similarity(tfidf_matrix)

# %%
indices = pd.Series(data.index, 
                    index=data['Title']).drop_duplicates()

# %%
def netFlix_recommendation(title, similarity = similarity):
    index = indices[title]
    similarity_scores = list(enumerate(similarity[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[0:10]
    movieindices = [i[0] for i in similarity_scores]
    return data['Title'].iloc[movieindices]

print(netFlix_recommendation("girlfriend"))
# Out:
# 3                          blackaf
# 285                     washington
# 417                 arrest develop
# 434     astronomi club sketch show
# 451    aunti donna big ol hous fun
# 656                      big mouth
# 752                bojack horseman
# 805                   brew brother
# 935                       champion
# 937                  chappell show
# Name: Title, dtype: object

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=360)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('AAPL', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
print(data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-10-11 00:00:00-04:00  142.270004  144.809998  141.809998  142.809998
# 2021-10-12 00:00:00-04:00  143.229996  143.250000  141.039993  141.509995
# 2021-10-13 00:00:00-04:00  141.240005  141.399994  139.199997  140.910004
# 2021-10-14 00:00:00-04:00  142.110001  143.880005  141.509995  143.759995
# 2021-10-15 00:00:00-04:00  143.770004  144.899994  143.509995  144.839996
#
#                             Adj Close    Volume
# Date
# 2021-10-11 00:00:00-04:00  142.014206  64452200
# 2021-10-12 00:00:00-04:00  140.721451  73035900
# 2021-10-13 00:00:00-04:00  140.124802  78762700
# 2021-10-14 00:00:00-04:00  142.958923  69907100
# 2021-10-15 00:00:00-04:00  144.032898  67940300

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
figure = px.line(data, x = data.index, y = "Close")
figure.show()

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=360)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('AAPL', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
print(data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-10-11 00:00:00-04:00  142.270004  144.809998  141.809998  142.809998
# 2021-10-12 00:00:00-04:00  143.229996  143.250000  141.039993  141.509995
# 2021-10-13 00:00:00-04:00  141.240005  141.399994  139.199997  140.910004
# 2021-10-14 00:00:00-04:00  142.110001  143.880005  141.509995  143.759995
# 2021-10-15 00:00:00-04:00  143.770004  144.899994  143.509995  144.839996
#
#                             Adj Close    Volume
# Date
# 2021-10-11 00:00:00-04:00  142.014206  64452200
# 2021-10-12 00:00:00-04:00  140.721451  73035900
# 2021-10-13 00:00:00-04:00  140.124802  78762700
# 2021-10-14 00:00:00-04:00  142.958908  69907100
# 2021-10-15 00:00:00-04:00  144.032898  67940300

# %%
data["Date"] = data.index
data = data[["Date", "Open", "High", 
             "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
#                        Date        Open        High         Low       Close  \
# 0 2021-10-11 00:00:00-04:00  142.270004  144.809998  141.809998  142.809998
# 1 2021-10-12 00:00:00-04:00  143.229996  143.250000  141.039993  141.509995
# 2 2021-10-13 00:00:00-04:00  141.240005  141.399994  139.199997  140.910004
# 3 2021-10-14 00:00:00-04:00  142.110001  143.880005  141.509995  143.759995
# 4 2021-10-15 00:00:00-04:00  143.770004  144.899994  143.509995  144.839996
#
#     Adj Close    Volume
# 0  142.014206  64452200
# 1  140.721451  73035900
# 2  140.124802  78762700
# 3  142.958908  69907100
# 4  144.032898  67940300

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "Apple Stock Price Analysis", 
                     xaxis_rangeslider_visible=False)
figure.show()
