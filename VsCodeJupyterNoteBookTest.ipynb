# %%
# !pip install pyspark

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv(r'C:\Users\siddi\Desktop\DesktopAll\sf_airbnb_listings.csv ')
# Out:
#             id                            listing_url     scrape_id  \
# 0          958       https://www.airbnb.com/rooms/958  2.020000e+13
# 1         5858      https://www.airbnb.com/rooms/5858  2.020000e+13
# 2         7918      https://www.airbnb.com/rooms/7918  2.020000e+13
# 3         8142      https://www.airbnb.com/rooms/8142  2.020000e+13
# 4         8339      https://www.airbnb.com/rooms/8339  2.020000e+13
# ...        ...                                    ...           ...
# 7570  35284961  https://www.airbnb.com/rooms/35284961  2.020000e+13
# 7571  35285751  https://www.airbnb.com/rooms/35285751  2.020000e+13
# 7572  35286441  https://www.airbnb.com/rooms/35286441  2.020000e+13
# 7573  35288483  https://www.airbnb.com/rooms/35288483  2.020000e+13
# 7574  35291911  https://www.airbnb.com/rooms/35291911  2.020000e+13
#
#      last_scraped                                               name  \
# 0        6/2/2019                Bright, Modern Garden Unit - 1BR/1B
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Test').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-1RTMFH2E:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv(r'C:\Users\siddi\Desktop\DesktopAll\sf_airbnb_listings.csv', header=True)

# %%
df_pyspark.show()
# Out:
# +--------------------+--------------------+-------------------+--------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+----------+--------------------+--------------+----------+--------------------+----------------+---------------+--------------------+--------------------+------------------+------------------+--------------------+--------------------+--------------------+--------------------+------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+--------------------+-------------+-----+-------+-------------+-----------------+------------+-------------+--------+----------+-----------------+-------------+---------------+------------+---------+----------+----+--
# ...

# %%
spark.read.option('header','true').csv(r'C:\Users\siddi\Desktop\DesktopAll\sf_airbnb_listings.csv').show()
# Out:
# +--------------------+--------------------+-------------------+--------------+--------------------+--------------------+--------------------+--------------------+-------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-------------+--------------------+--------------+----------+--------------------+----------------+---------------+--------------------+--------------------+------------------+------------------+--------------------+--------------------+--------------------+--------------------+------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+-------------+----------------------+----------------------------+-------------+-----+-------+-------------+-----------------+------------+-------------+--------+----------+-----------------+-------------+---------------+------------+-------
# ...

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(_c0='id', _c1='listing_url', _c2='scrape_id', _c3='last_scraped', _c4='name', _c5='summary', _c6='space', _c7='description', _c8='experiences_offered', _c9='neighborhood_overview', _c10='notes', _c11='transit', _c12='access', _c13='interaction', _c14='house_rules', _c15='thumbnail_url', _c16='medium_url', _c17='picture_url', _c18='xl_picture_url', _c19='host_id', _c20='host_url', _c21='host_name', _c22='host_since', _c23='host_location', _c24='host_about', _c25='host_response_time', _c26='host_response_rate', _c27='host_acceptance_rate', _c28='host_is_superhost', _c29='host_thumbnail_url', _c30='host_picture_url', _c31='host_neighbourhood', _c32='host_listings_count', _c33='host_total_listings_count', _c34='host_verifications', _c35='hos1_has_pro0ile_pic', _c36='hos1_iden1i1y_veri0ied', _c37='street', _c38='neighbourhood', _c39='neighbourhood_cleansed', _c40='neighbourhood_group_cleansed', _c41='city', _c42='state', _c43='zipcode', _c44='market', _c45='smart_location', _c46='cou
# ...

# %%
conda install posix
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\siddi\anaconda3
#
#   added / updated specs:
#     - posix
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.14.0               |   py39haa95532_0         937 KB
#     m2-base-1.0.0              |                3         178 KB
#     m2-bash-completion-2.3     |                2         187 KB
#     m2-catgets-1.1             |                3          26 KB
#     m2-coreutils-8.25          |              102         4.7 MB
#     m2-dash-0.5.8              |                2          94 KB
#     m2-diffutils-3.3           |                4         343 KB
#     m2-file-5.25               |                2         792 KB
#     m2-filesystem-2016.04      |                4          26 KB
#     m2-findutils-4.6.0         |                2         635 KB
# ...

# %%
# !ls
# Out:
# Algorithms-master
# DatabaseConnect.ipynb
# Demo
# Practice
# README.md
# Selenium
# VsCodeJupyterNoteBookTest.ipynb
# learningspring
# mailroom
# mailroom-webapp
# smiota-server-code
# spark-3.3.0-bin-hadoop3
# spark-3.3.0-bin-hadoop3.tgz
# sprint-web
# test1 - Sheet1.csv
# testspringvscode
# ui-automation
# urban
# web-app-test
# webtest

# %%
# !tar xf spark-3.3.0-bin-hadoop3.tgz
# !pip install -q findspark

# %%
# !ls
# Out:
# Algorithms-master
# DatabaseConnect.ipynb
# Demo
# Practice
# README.md
# Selenium
# VsCodeJupyterNoteBookTest.ipynb
# learningspring
# mailroom
# mailroom-webapp
# smiota-server-code
# spark-3.3.0-bin-hadoop3
# spark-3.3.0-bin-hadoop3.tgz
# sprint-web
# test1 - Sheet1.csv
# testspringvscode
# ui-automation
# urban
# web-app-test
# webtest

# %%
import findspark
findspark.init()
from pyspark import SparkContext

# %%
sc = SparkContext.getOrCreate()
sc
# Out:
# <SparkContext master=local[*] appName=Test>

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-1RTMFH2E:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark.show(2)
# Out:
# +----+--------------------+---------+------------+--------------------+--------------------+--------------------+--------------------+-------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+----------+--------------------+--------------+-------+--------------------+----------------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+-------------+----------------------+----------------------------+-------------+-----+-------+-------------+-----------------+------------+-------------+--------+----------+-----------------+-------------+---------------+------------+---------+--------+----+--------+--------------------
# ...

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- listing_url: string (nullable = true)
#  |-- scrape_id: string (nullable = true)
#  |-- last_scraped: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- space: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- experiences_offered: string (nullable = true)
#  |-- neighborhood_overview: string (nullable = true)
#  |-- notes: string (nullable = true)
#  |-- transit: string (nullable = true)
#  |-- access: string (nullable = true)
#  |-- interaction: string (nullable = true)
#  |-- house_rules: string (nullable = true)
#  |-- thumbnail_url: string (nullable = true)
#  |-- medium_url: string (nullable = true)
#  |-- picture_url: string (nullable = true)
#  |-- xl_picture_url: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_url: string (nullable = true)
#  |-- host_name: string (nullable = true)
# ...

# %%
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, BooleanType, DoubleType, IntegerType

# %%
df_pyspark.columns
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'hos1_has_pro0ile_pic',
#  'hos1_iden1i1y_veri0ied',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_loca1ion_exac1',
# ...

# %%
StructType([StructField=('id',
 'listing_url',
 'scrape_id',
 'last_scraped',
 'name',
 'summary',
 'space',
 'description',
 'experiences_offered',
 'neighborhood_overview',
 'notes',
 'transit',
 'access',
 'interaction',
 'house_rules',
 'thumbnail_url',
 'medium_url',
 'picture_url',
 'xl_picture_url',
 'host_id',
 'host_url',
 'host_name',
 'host_since',
 'host_location',
 'host_about',
 'host_response_time',
 'host_response_rate',
 'host_acceptance_rate',
 'host_is_superhost',
 'host_thumbnail_url',
 'host_picture_url',
 'host_neighbourhood',
 'host_listings_count',
 'host_total_listings_count',
 'host_verifications',
 'hos1_has_pro0ile_pic',
 'hos1_iden1i1y_veri0ied',
 'street',
 'neighbourhood',
 'neighbourhood_cleansed',
 'neighbourhood_group_cleansed',
 'city',
 'state',
 'zipcode',
 'market',
 'smart_location',
 'country_code',
 'country',
 'latitude',
 'longitude',
 'is_loca1ion_exac1',
 'property_type',
 'room_type',
 'accommodates',
 'bathrooms',
 'bedrooms',
 'beds',
 'bed_type',
 'amenities',
 'square_feet',
 'price',
 'weekly_price',
 'monthly_price',
 'security_deposit',
 'cleaning_fee',
 'guests_included',
 'extra_people',
 'minimum_nights',
 'maximum_nights',
 'minimum_minimum_nights',
 'maximum_minimum_nights',
 'minimum_maximum_nights',
 'maximum_maximum_nights',
 'minimum_nights_avg_ntm',
 'maximum_nights_avg_ntm',
 'calendar_updated',
 'has_availabili1y',
 'availability_30',
 'availability_60',
 'availability_90',
 'availability_365',
 'calendar_last_scraped',
 'number_of_reviews',
 'number_of_reviews_ltm',
 'first_review',
 'last_review',
 'review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value',
 'requires_license',
 'license',
 'jurisdiction_names',
 'ins1an1_bookable',
 'is_business_1ravel_ready',
 'cancellation_policy',
 'require_gues1_pro0ile_pic1ure',
 'require_gues1_phone_veri0ica1ion',
 'calculated_host_listings_count',
 'calculated_host_listings_count_entire_homes',
 'calculated_host_listings_count_private_rooms',
 'calculated_host_listings_count_shared_rooms',
 'reviews_per_month')
])

# %%
input =  "I am Syed Siddiq. I am from California"

def reverseString(intput):
    list = []
    for w in input.split(" "):
        if '.' in w:
            w = '.' + w[:-1]
        list.append(w + " ")
    list = reversed(list)
    return "".join(list)

# %%
input =  "I am Syed Siddiq. I am from California"
print(reverseString(input))
# Out:
# California from am I .Siddiq Syed am I

# %%
def smallestMatrix(input):
    m = []
    for i in range(len(input)):
        m.append(max(input[i]))
    return max(m)

# %%
mat = [[1,  44, 77],[8,  27, 12],[22,  14,  90]]

# %%
print(smallestMatrix(mat))
# Out:
# 90
